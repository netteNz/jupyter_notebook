# %%
import matplotlib.pyplot as plt
import numpy as np

# Solving a system of linear equations utilizing linalg.solve() method.
# 1- y = 2x
# 2 3x + y = 10

line_1 = np.array([[-2,1],[3,1]])
line_2 = np.array([0,10])

product = np.linalg.solve(line_1, line_2)
print(product)

# 1st position on the stdout is the value of x, the second is the value of y
# Utilizing the pyplot library, we plot our graph
plt.plot(line_one, line_two)
plt.show()
# Out:
# [2. 4.]

# %%
plt.pyplot
